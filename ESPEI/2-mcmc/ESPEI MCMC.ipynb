# %% [markdown]
# # ESPEI
#
# ### Extensible Self-optimizating Phase Equilibria Infrastructure
#
# Documentation for internal and external APIs can be found at https://espei.org
#
# Solutions to this notebook can be found at https://github.com/materialsgenomefoundation/2023-workshop-material
#
# ## Markov Chain Monte Carlo (MCMC)
#
# ### Running MCMC
#
# The most minimal MCMC settings file that could be used for ESPEI only requires setting the source of the database (i.e. the database from parameter selection) and the number of iterations.
#
# ```yaml
# system:
#   phase_models: phases.json
#   datasets: input-data/run
# output:
#   output_db:  mcmc.tdb
#   verbosity:  2
# mcmc:
#   iterations: 100
#   input_db: generated.tdb
# ```
#
# By default, ESPEI will run in parallel using the `dask` package. If you try to run this locally, you may need to do an [extra step to configure dask](https://espei.org/en/latest/installation.html#configuration).
#
# However, since we are using limited and shared cloud resources, we will make some compromises in terms of accuracy and storage. The settings we'll use for running MCMC simulations are as follows (saved as `mcmc_settings.yaml`):
#
# ```yaml
# system:
#   phase_models: ../phase_models.json      # path to the phases file
#   datasets: ../input-data  # path to the directory containing input data
#   tags:
#     dft:
#       excluded_model_contributions: ['idmix', 'mag']
#     estimated-entropy:
#       excluded_model_contributions: ['idmix', 'mag']
# output:
#   output_db: Cu-Mg-mcmc.tdb               # what to name the output TDB file
#   verbosity: 1                            # levels of verbosity. Choose 0, 1 or 2 for Warnings, Info, or Debug
#   tracefile: null  # don't write out this file
#   probfile:  null  # don't write out this file
#   logfile:   null  # write output to console
# mcmc:
#   iterations: 2
#   save_interval: 1
#   scheduler: null  # don't parallelize, just run on one core
#   input_db: Cu-Mg-generated.tdb
#   prior:
#     name: normal
#     loc_relative: 1.0
#     scale_relative: 1.0
# ```
#
# All MCMC options are explained in [ESPEI's YAML settings file documentation](https://espei.org/en/latest/writing_input.html#mcmc). Compared to parameter generation, the options are more extensive and worth being familiar with.

# %%
import yaml
from espei import run_espei
from pycalphad import Database, binplot, equilibrium, variables as v

# %%
with open('mcmc_settings.yaml') as fp:
    mcmc_settings = yaml.safe_load(fp)

# %% [markdown]
# Now we'll run the MCMC simulation for just two iterations. The outputs are the database which has the most optimal parameters of all samples and an `emcee.EnsembleSampler` object that contains the trace (contains samples of the parameters for every chain and iteration) and the log-likelihood.

# %%
dbf_mcmc, sampler = run_espei(mcmc_settings)
# Out:
# INFO:espei.espei_script - espei version       0.9.1
# INFO:espei.espei_script - pycalphad version   0.11.2
# INFO:espei.espei_script - dask version        2026.3.0
# INFO:espei.espei_script - distributed version 2026.3.0
# INFO:espei.espei_script - symengine version   0.13.0
# INFO:espei.espei_script - emcee version       2.2.1
# INFO:espei.espei_script - If you use ESPEI for work presented in a publication, we ask that you cite the following paper:
#     B. Bocklund, R. Otis, A. Egorov, A. Obaied, I. Roslyakova, Z.-K. Liu, ESPEI for efficient thermodynamic database development, modification, and uncertainty quantification: application to Cu-Mg, MRS Commun. (2019) 1-10. doi:10.1557/mrc.2019.59.
# TRACE:espei.espei_script - Loading and checking datasets.
# TRACE:espei.espei_script - Finished checking datasets
# INFO:espei.espei_script - Not using a parallel scheduler. ESPEI is running MCMC on a single core.
# INFO:espei.error_functions.context - Fitting 22 degrees of freedom.
# TRACE:espei.error_functions.context - Getting residual object for ActivityResidual
# TRACE:espei.error_functions.context - Finished getting residual object for ActivityResidual in 0.00 s
# TRACE:espei.error_functions.context - Getting residual object for FixedConfigurationPropertyResidual
# TRACE:espei.error_functions.context - Finished getting residual object for FixedConfigurationPropertyResidual in 0.14 s
# TRACE:espei.error_functions.context - Getting residual object for ZPFResidual
# TRACE:espei.error_functions.context - Finished getting residual object for ZPFResidual in 0.23 s
# TRACE:espei.error_functions.context - Getting residual object for EquilibriumPropertyResidual
# TRACE:espei.error_functions.context - Finished getting residual object for EquilibriumPropertyResidual in 0.00 s
# INFO:espei.optimizers.opt_mcmc - Initializing a normal prior for the parameters.
# TRACE:espei.optimizers.opt_mcmc - Probability for initial parameters
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.37s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -433.484 (0.21 s). ZPFResidual: -4714.154 (1.16 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5147.638.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.5736, lnlike: -5147.6375, lnprob: -5319.2111
# TRACE:espei.optimizers.opt_mcmc - Initial parameters: [-3.25395e+04  1.32000e+01 -2.74381e+00  8.23630e+03  4.89196e+00 -1.46750e+04 -2.44412e+04  2.01496e+04  4.65000e+04 -1.55010e+01 -3.95913e+04  1.57200e+01  1.04160e+05 -3.47190e+01  2.10000e+04 -6.99900e+00  1.77720e+04  2.12400e+04  5.10644e+00 -8.72053e+03  1.14282e+01 -3.44376e+04]
# INFO:espei.optimizers.opt_mcmc - Initializing 44 chains with 2 chains per parameter.
# INFO:espei.optimizers.opt_mcmc - Using a deterministic ensemble sampler.
# INFO:espei.optimizers.opt_mcmc - Running MCMC for 2 iterations.
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.19s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -433.484 (0.15 s). ZPFResidual: -4714.154 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5147.638.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.5736, lnlike: -5147.6375, lnprob: -5319.2111
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.14s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -531.466 (0.11 s). ZPFResidual: -4738.516 (1.03 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5269.982.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6993, lnlike: -5269.9818, lnprob: -5441.6812
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -583.792 (0.11 s). ZPFResidual: -5721.584 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -6305.376.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6713, lnlike: -6305.3761, lnprob: -6477.0474
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -500.719 (0.11 s). ZPFResidual: -4215.595 (1.05 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -4716.314.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6728, lnlike: -4716.3143, lnprob: -4887.9871
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -562.562 (0.11 s). ZPFResidual: -5706.365 (1.03 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -6268.927.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.7296, lnlike: -6268.9270, lnprob: -6440.6566
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.17s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -630.793 (0.11 s). ZPFResidual: -5196.047 (1.06 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5826.841.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6892, lnlike: -5826.8407, lnprob: -5998.5299
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.13s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -538.569 (0.09 s). ZPFResidual: -6756.011 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -7294.580.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6643, lnlike: -7294.5799, lnprob: -7466.2442
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -569.043 (0.10 s). ZPFResidual: -5059.678 (1.05 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5628.722.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6558, lnlike: -5628.7217, lnprob: -5800.3775
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -492.824 (0.11 s). ZPFResidual: -4969.413 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5462.237.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6748, lnlike: -5462.2372, lnprob: -5633.9120
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.13s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -550.613 (0.09 s). ZPFResidual: -6638.217 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -7188.830.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6731, lnlike: -7188.8303, lnprob: -7360.5034
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.17s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -572.881 (0.11 s). ZPFResidual: -4699.320 (1.06 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5272.201.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6526, lnlike: -5272.2013, lnprob: -5443.8538
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.16s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -690.507 (0.11 s). ZPFResidual: -4502.151 (1.05 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5192.658.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.7416, lnlike: -5192.6579, lnprob: -5364.3995
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.14s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -734.348 (0.11 s). ZPFResidual: -10289.523 (1.03 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -11023.872.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.7314, lnlike: -11023.8717, lnprob: -11195.6031
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.16s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -500.233 (0.11 s). ZPFResidual: -4525.364 (1.05 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5025.597.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6355, lnlike: -5025.5966, lnprob: -5197.2321
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.14s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -541.535 (0.11 s). ZPFResidual: -9155.366 (1.03 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -9696.901.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.7281, lnlike: -9696.9009, lnprob: -9868.6290
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.18s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -608.099 (0.11 s). ZPFResidual: -4915.316 (1.07 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5523.416.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6665, lnlike: -5523.4157, lnprob: -5695.0822
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.15s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual: -516.389 (0.11 s). ZPFResidual: -4750.632 (1.04 s). EquilibriumPropertyResidual: 0.000 (0.00 s). Total: -5267.021.
# TRACE:espei.optimizers.opt_mcmc - Proposal - lnprior: -171.6646, lnlike: -5267.0210, lnprob: -5438.6856
# TRACE:espei.optimizers.opt_mcmc - Likelihood - 1.14s - ActivityResidual: 0.000 (0.00 s). FixedConfigurationPropertyResidual:
# %% [markdown]
# The key output from the sampler are the trace (`emcee` calls this the "chain") and the log-probability (lnprob). The trace has the shape `(number of chains, number of iterations, number of parameters)`. The log-probability has the shape  `(number of chains, number of iterations)`.

# %%
trace = sampler.chain
lnprob = sampler.lnprobability

print(f"Trace shape:           {trace.shape}")
print(f"Log-probability shape: {lnprob.shape}")
# Out:
# Trace shape:           (44, 2, 22)
# Log-probability shape: (44, 2)

# %% [markdown]
# With the MCMC simulation complete, we can see what the phase diagram looks like.

# %%
from espei.plot import dataplot
from espei.datasets import recursive_glob, load_datasets

# load our JSON datasets into an in-memory database
datasets = load_datasets(recursive_glob('../input-data', '*.json'))

# %%
dbf_start = Database('Cu-Mg-generated.tdb')
comps = ['CU', 'MG']
phases = ['FCC_A1', 'HCP_A3', 'LIQUID', 'CUMG2', 'LAVES_C15']
conds = {v.N: 1.0, v.P: 101325, v.T: (300, 2300, 20), v.X('MG'): (0, 1, 0.02)}
ax = binplot(dbf_start, comps, phases, conds)
dataplot(comps, phases, conds, datasets, ax=ax)
# Out:
# <Axes: title={'center': 'Cu-Mg'}, xlabel='X(*, Mg)', ylabel='Temperature (K)'>

# %%
comps = ['CU', 'MG']
phases = ['FCC_A1', 'HCP_A3', 'LIQUID', 'CUMG2', 'LAVES_C15']
conds = {v.N: 1.0, v.P: 101325, v.T: (300, 2300, 20), v.X('MG'): (0, 1, 0.02)}
ax = binplot(dbf_mcmc, comps, phases, conds)
dataplot(comps, phases, conds, datasets, ax=ax)
# Out:
# <Axes: title={'center': 'Cu-Mg'}, xlabel='X(*, Mg)', ylabel='Temperature (K)'>

# %% [markdown]
# After just a few MCMC iterations through 44 chains, the phase diagram shows a small change.

# %% [markdown]
# ### Simulated MCMC analysis
#
# Typically, a fully converged MCMC simulation with enough samples to do uncertainty quantification will require a few hundred to a few thousand calculations.
#
#
# Since performing an MCMC simulation for a significant period of time is not possible in this workshop, an existing pre-computed trace and log-probability are loaded that took 1000 iterations of sampling 40 chains for a total of 40,000 samples in parameter space. These 40,000 samples took 3.5 hours to run across 6 cores on a 2015 MacBook Pro (2.2 GHz Intel i7).

# %%
import numpy as np
from espei.analysis import truncate_arrays

# %%
trace = np.load('trace.npy')
lnprob = np.load('lnprob.npy')

trace, lnprob = truncate_arrays(trace, lnprob)

print(trace.shape)
print(lnprob.shape)
# Out:
# (88, 2000, 22)
# (88, 2000)

# %% [markdown]
# #### Visualizing convergence of the simulation

# %%
import matplotlib.pyplot as plt
plt.plot(lnprob.T)
plt.title('Log-probability convergence\n(1 line = 1 chain)')
plt.xlabel('Iterations')
plt.ylabel('Log-probability')

plt.figure()
plt.plot(lnprob.T)
plt.title('Zoomed Log-probability convergence\n(1 line = 1 chain)')
plt.xlabel('Iterations')
plt.ylabel('Log-probability')
plt.ylim(-5000, -4500)
# Out:
# (-5000.0, -4500.0)

# %% [markdown]
# #### Visualizing change in a particular parameter

# %%
# index of parameter of interest within the chain
# could be looped to produce figures for all parameters
parameter_idx = 5

num_chains = trace.shape[0]
ax = plt.figure().gca()
ax.set_xlabel('Iterations')
ax.set_ylabel('Parameter value')
ax.plot(trace[..., parameter_idx].T)
ax.set_title('Parameter Convergence')
# Out:
# Text(0.5, 1.0, 'Parameter Convergence')

# %% [markdown]
# #### Finding the optimal set of parameters and plotting the phase diagram
#
# An MCMC simulation has many samples, but we are still likely interested in getting the set of parameters that's the best point estimate of the data.
#
# ESPEI provides an `optimal_parameters` function that will extract the parameter set with the highest log-probability, which can be used to update the symbols that we fit in the database ($ \mathrm{VV0001} $, ...)..

# %%
from espei.utils import database_symbols_to_fit, optimal_parameters
import copy

# make an in-memory copy of the database because updating the
# symbols with the optimal solutions will erase the old ones
dbf_opt = copy.deepcopy(dbf_mcmc)

# Find the optimal parameters and replace the values in the symbols dictionary
opt_params = dict(zip(database_symbols_to_fit(dbf_opt), optimal_parameters(trace, lnprob)))
dbf_opt.symbols.update(opt_params)

# %%
# plot the phase diagram

ax = binplot(dbf_opt, comps, phases, conds)
dataplot(comps, phases, conds, datasets, ax=ax)
# Out:
# <Axes: title={'center': 'Cu-Mg'}, xlabel='X(*, Mg)', ylabel='Temperature (K)'>
